# %%
import pandas as pd

# %%
df = pd.read_csv('../data/filtered/Fil_SCF_20022.csv', index_col=0)

# %%
df.columns
# Out:
# Index(['RETQLIQ', 'INCOME', 'FIN', 'NFIN', 'DEBT', 'EQUITY', 'STOCKS',
#        'HHOUSES', 'LIQ', 'YESFINRISK', 'SPENDMOR', 'LATE', 'EMERGSAV',
#        'FINLIT', 'AGE', 'EDUC', 'MARRIED', 'KIDS', 'OCCAT1', 'BUS'],
#       dtype='str')

# %%
df[df['INCOME'] == 0][['RETQLIQ', 'INCOME', 'FIN', 'DEBT', 'EQUITY', 'AGE']]
# Out:
#        RETQLIQ  INCOME        FIN      DEBT      EQUITY  AGE
# 420     475000     0.0    1270000   1100500    667000.0   46
# 1295         0     0.0        210    490000         0.0   78
# 1490     46000     0.0    3324970     82000    853000.0   52
# 1990    720000     0.0    1809000    780000    932000.0   62
# 3060         0     0.0      14000      3000         0.0   40
# 3660   1280000     0.0    6000230   3285000   4450000.0   52
# 4290         0     0.0    2427000         0      9000.0   75
# 4980   2248000     0.0    5491800         0    152110.0   61
# 6800    109000     0.0     117000     84000     69000.0   57
# 7360     61000     0.0      85400         0         0.0   59
# 7370         0     0.0     121300     92920         0.0   60
# 8210         0     0.0        980         0         0.0   62
# 8660         0     0.0      83000     60000      8000.0   26
# 9905    924000     0.0   56913000   2060000  31732700.0   57
# 11230   150000     0.0    1240000   1250000    700000.0   46
# 12145        0     0.0      43000     48000         0.0   57
# 12160   800000     0.0    3550000         0   3300000.0   67
# 12320        0     0.0   64897000         0  28250000.0   89
# 12760        0     0.0       5000    346020         0.0   62
# 13575        0     0.0      73000      8200     15000.0   34
# 13795        0     0.0    1745000    467100    500000.0   59
# 14050        0     0.0   17191500   1455000         0.0   66
# 14355    32000     0.0     752000    830000    735000.0   52
# 16220        0     0.0   14635000         0   3765000.0   49
# 16370   700000     0.0     783500    317700    150000.0   56
# 16385   937000     0.0    1057000      8800    937000.0   56
# 16430  6543000     0.0    8553000   2460000   4271500.0   70
# 16930  4407000     0.0   10295300   1770000   8391300.0   62
# 17210   630000     0.0   42982000     19000  32800000.0   57
# 17220   400000     0.0    1263000         0    250000.0   64
# 19030  1419000     0.0    9462000    185000   6519000.0   50
# 19790  1535000     0.0  111045000  27390000  70658500.0   65
# 20665        0     0.0       4000      1000         0.0   61
# 20760        0     0.0      98000   1250000         0.0   73
# 20910        0     0.0        100         0         0.0   25
# 21140        0     0.0       4801         0         0.0   38
# 21835        0     0.0        630         0         0.0   59
# 22035   385000     0.0   11460100    250000  10010000.0   70
# 22660        0     0.0    4370000     11000   1750000.0   59
